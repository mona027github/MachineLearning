# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
iris = load_iris()
X = iris.data
y = iris.target

# 1. Scale the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 2. Create PCA object
pca = PCA(n_components=2)   # choose number of components
X_pca = pca.fit_transform(X_scaled)

# 3. Get explained variance ratio
explained_var = pca.explained_variance_ratio_ * 100
print("Explained variance ratio (%):", explained_var)

# 4. Plot PCA result
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap="viridis")
plt.xlabel("PC1 (%.2f%%)" % explained_var[0])
plt.ylabel("PC2 (%.2f%%)" % explained_var[1])
plt.title("PCA on Iris Dataset")
plt.colorbar()
plt.show()
# Out:
# Explained variance ratio (%): [72.96244541 22.85076179]

# %%
X_Setosa  = X[y==0]
scaler = StandardScaler()
X_scaled =scaler.fit_transform(X_Setosa)

pca = PCA(n_components =2)
X_pca = pca.fit_transform(X_scaled)

plt.scatter(X_pca[:, 0], X_pca[:, 1], c='blue')
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("PCA on Setosa")
plt.show()

# %%
X_Versicolor  = X[y==1]
scaler = StandardScaler()
X_scaled =scaler.fit_transform(X_Versicolor)

pca = PCA(n_components =2)
X_pca = pca.fit_transform(X_scaled)

plt.scatter(X_pca[:, 0], X_pca[:, 1], c='green')
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("PCA on Versicolor")
plt.show()

# %%
X_Versicolor  = X[y==1]
scaler = StandardScaler()
X_scaled =scaler.fit_transform(X_Versicolor)

pca = PCA(n_components =2)
X_pca = pca.fit_transform(X_scaled)

plt.scatter(X_pca[:, 0], X_pca[:, 1], c='green')
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("PCA on Versicolor")
plt.show()

# %%
X_Virginica  = X[y==2]
scaler = StandardScaler()
X_scaled =scaler.fit_transform(X_Virginica)

pca = PCA(n_components =2)
X_pca = pca.fit_transform(X_scaled)

plt.scatter(X_pca[:, 0], X_pca[:, 1], c='red')
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("PCA on Virginica")
plt.show()
