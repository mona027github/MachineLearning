# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs, make_classification

# %%
X_blobs, y_blobs = make_blobs(n_samples=200, centers=3, random_state=42, cluster_std=1.5)
# print(X_blobs)
# print(y_blobs)
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.scatter(X_blobs[:, 0], X_blobs[:, 1], c=y_blobs, cmap='viridis', s=40, edgecolors='k')
plt.title("Dataset from make_blobs()")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.grid(True)
# Out:
# [[ 7.43854060e+00  2.68391907e+00]
#  [-6.43881528e+00  1.02471399e+01]
#  [-6.89799735e+00 -8.22599115e+00]
#  [-9.05175370e+00 -8.99130525e+00]
#  [-7.76367433e+00 -5.60570645e+00]
#  [-5.75868678e+00 -5.96455420e+00]
#  [-2.79773907e+00  9.46660714e+00]
#  [-7.58618465e+00 -6.53203469e+00]
#  [ 4.24289359e+00  6.05342343e+00]
#  [-5.66033401e+00 -5.93566633e+00]
#  [ 3.24948313e+00  1.88388165e+00]
#  [ 4.98106874e+00  3.93388382e+00]
#  [ 6.26445570e+00  3.55387276e+00]
#  [ 3.91183351e+00  2.09598089e+00]
#  [ 1.60216496e+00  2.25285116e+00]
#  [-8.12311971e+00 -7.72038115e+00]
#  [-2.61721281e+00  1.05195855e+01]
#  [-8.11295778e+00 -6.51457878e+00]
#  [ 5.66926912e+00 -4.45904123e-01]
#  [-4.50060197e+00 -8.73683284e+00]
#  [ 7.82311313e+00  3.52186757e+00]
#  [ 3.92746087e+00  9.93175835e-01]
#  [-6.39554935e+00 -8.12095601e+00]
#  [-2.40790532e+00  6.87716385e+00]
#  [-5.85669773e+00 -7.34550973e+00]
#  [-3.52458062e+00  9.93180056e+00]
#  [-4.23568799e+00  9.57783316e+00]
# ...

# %%
plt.scatter(X[:, 0], y)

# %%
plt.scatter( X[:, 1], y)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 plt.scatter( X[:, 1], y)
#
# IndexError: index 1 is out of bounds for axis 1 with size 1

# %%
X_class, y_class = make_classification( n_samples=200, n_features=2, n_redundant=0, n_informative=2,n_clusters_per_class=1, n_classes=3, random_state=42)
plt.subplot(1, 2, 2)
plt.scatter(X_class[:, 0], X_class[:, 1], c=y_class, cmap='coolwarm', s=40, edgecolors='k')
plt.title("Dataset from make_classification()")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
from sklearn.datasets import make_blobs
X, y = make_blobs(n_samples=10, centers=3, n_features=1,random_state=0)
print(X.shape)
print(y)
# Out:
# (10, 1)
# [1 1 2 1 2 0 2 0 0 0]

# %%
X, y = make_blobs(n_samples=[3, 3, 4], centers=None, n_features=1,random_state=0)
print(X.shape)
print(y)
# Out:
# (10, 1)
# [2 1 2 1 2 0 2 1 0 0]
